# %% [markdown]
# # 02. Two Pointer / Sliding Window
#
# **핵심**: O(n²)를 O(n)으로. 양끝 조이기 / 구간 늘렸다 줄이기
#
# ## 언제 투포인터를 쓰냐
# - 정렬된 배열 + 합/차 조건 → 양끝 투포인터
# - 연속 구간 + 조건 만족 → 슬라이딩 윈도우
# - "최소/최대 구간" → 윈도우 늘렸다 줄이기
#
# ## 템플릿
# ```python
# # 양끝 투포인터
# left, right = 0, len(arr) - 1
# while left < right:
#     if 조건:
#         left += 1
#     else:
#         right -= 1
#
# # 슬라이딩 윈도우
# left = 0
# for right in range(len(arr)):
#     # 윈도우에 arr[right] 추가
#     while 윈도우가_조건_초과:
#         # arr[left] 제거
#         left += 1
#     # 답 갱신
# ```
#
# ---

# %% [markdown]
# ## 1. Valid Palindrome (LC 125) - Easy
# https://leetcode.com/problems/valid-palindrome/
#
# **패턴**: 양끝 투포인터 + 필터링
#
# **문제**: 문자열 s가 주어질 때, 영숫자만 고려하고 대소문자 무시하여 팰린드롬인지 판별하라.
#
# ```
# Input: s = "A man, a plan, a canal: Panama" → True
# Input: s = "race a car" → False
# ```

# %%
def is_palindrome(s: str) -> bool:
    # 여기에 풀이 작성
    pass

# %%
# 테스트
assert is_palindrome("A man, a plan, a canal: Panama") == True
assert is_palindrome("race a car") == False
assert is_palindrome(" ") == True
assert is_palindrome("") == True
print("All tests passed!")

# %% [markdown]
# ### 복기
# - 왜 이 패턴인지:
# - 시간/공간 복잡도:
# - 오늘 실수:
#
# ---

# %% [markdown]
# ## 2. Two Sum II - Sorted (LC 167) - Medium
# https://leetcode.com/problems/two-sum-ii-input-array-is-sorted/
#
# **패턴**: 정렬된 배열 양끝 조이기
#
# **문제**: 정렬된 배열 numbers와 target이 주어질 때, 합이 target인 두 수의 인덱스를 반환하라. (1-indexed)
#
# ```
# Input: numbers = [2,7,11,15], target = 9
# Output: [1, 2]
# ```

# %%
from typing import List

def two_sum_sorted(numbers: List[int], target: int) -> List[int]:
    # 여기에 풀이 작성
    pass

# %%
# 테스트
assert two_sum_sorted([2, 7, 11, 15], 9) == [1, 2]
assert two_sum_sorted([2, 3, 4], 6) == [1, 3]
assert two_sum_sorted([-1, 0], -1) == [1, 2]
print("All tests passed!")

# %% [markdown]
# ### 복기
# - 왜 이 패턴인지:
# - 시간/공간 복잡도:
# - 오늘 실수:
#
# ---

# %% [markdown]
# ## 3. 3Sum (LC 15) - Medium
# https://leetcode.com/problems/3sum/
#
# **패턴**: 하나 고정 + 양끝 투포인터
#
# **문제**: 정수 배열 nums에서 합이 0인 세 수 조합을 모두 찾아라. 중복 조합은 제거.
#
# ```
# Input: nums = [-1, 0, 1, 2, -1, -4]
# Output: [[-1, -1, 2], [-1, 0, 1]]
# ```

# %%
from typing import List

def three_sum(nums: List[int]) -> List[List[int]]:
    # 여기에 풀이 작성
    pass

# %%
# 테스트
result = three_sum([-1, 0, 1, 2, -1, -4])
expected = [[-1, -1, 2], [-1, 0, 1]]
assert sorted([sorted(x) for x in result]) == sorted([sorted(x) for x in expected])
assert three_sum([0, 1, 1]) == []
assert three_sum([0, 0, 0]) == [[0, 0, 0]]
print("All tests passed!")

# %% [markdown]
# ### 복기
# - 왜 이 패턴인지:
# - 시간/공간 복잡도:
# - 오늘 실수:
#
# ---

# %% [markdown]
# ## 4. Container With Most Water (LC 11) - Medium
# https://leetcode.com/problems/container-with-most-water/
#
# **패턴**: 양끝에서 좁히기 (그리디)
#
# **문제**: 높이 배열 height가 주어질 때, 두 막대가 만드는 컨테이너에 담길 수 있는 물의 최대량을 구하라.
#
# ```
# Input: height = [1,8,6,2,5,4,8,3,7]
# Output: 49
# ```

# %%
from typing import List

def max_area(height: List[int]) -> int:
    # 여기에 풀이 작성
    pass

# %%
# 테스트
assert max_area([1, 8, 6, 2, 5, 4, 8, 3, 7]) == 49
assert max_area([1, 1]) == 1
assert max_area([4, 3, 2, 1, 4]) == 16
print("All tests passed!")

# %% [markdown]
# ### 복기
# - 왜 이 패턴인지:
# - 시간/공간 복잡도:
# - 오늘 실수:
#
# ---

# %% [markdown]
# ## 5. Longest Substring Without Repeating Characters (LC 3) - Medium
# https://leetcode.com/problems/longest-substring-without-repeating-characters/
#
# **패턴**: 가변 크기 슬라이딩 윈도우
#
# **문제**: 문자열 s에서 중복 문자 없는 가장 긴 부분 문자열의 길이를 구하라.
#
# ```
# Input: s = "abcabcbb" → 3  ("abc")
# Input: s = "bbbbb" → 1
# ```

# %%
def length_of_longest_substring(s: str) -> int:
    # 여기에 풀이 작성
    pass

# %%
# 테스트
assert length_of_longest_substring("abcabcbb") == 3
assert length_of_longest_substring("bbbbb") == 1
assert length_of_longest_substring("pwwkew") == 3
assert length_of_longest_substring("") == 0
print("All tests passed!")

# %% [markdown]
# ### 복기
# - 왜 이 패턴인지:
# - 시간/공간 복잡도:
# - 오늘 실수:
