# %% [markdown]
# # 03. Stack / Queue
#
# **핵심**: 순서가 중요한 문제. "마지막에 넣은 걸 먼저" vs "먼저 넣은 걸 먼저"
#
# ## 언제 스택/큐를 쓰냐
# - 괄호, 짝 맞추기 → 스택
# - "이전/다음 큰 수" → 단조 스택
# - FIFO 순서 처리, BFS → 큐/덱
# - 되돌리기(undo) → 스택
#
# ## 템플릿
# ```python
# # 스택 기본
# stack = []
# for char in s:
#     if stack and 매칭_조건:
#         stack.pop()
#     else:
#         stack.append(char)
#
# # 단조 스택 (다음 큰 수)
# stack = []  # 인덱스 저장
# for i in range(len(nums)):
#     while stack and nums[i] > nums[stack[-1]]:
#         idx = stack.pop()
#         result[idx] = nums[i]
#     stack.append(i)
# ```
#
# ---

# %% [markdown]
# ## 1. Valid Parentheses (LC 20) - Easy
# https://leetcode.com/problems/valid-parentheses/
#
# **패턴**: 스택 기본 - 괄호 매칭
#
# **문제**: `(`, `)`, `{`, `}`, `[`, `]`로만 이루어진 문자열 s가 주어질 때, 괄호가 올바르게 닫혀있는지 판별하라.
#
# ```
# "()" → True
# "()[]{}" → True
# "(]" → False
# ```

# %%
def is_valid(s: str) -> bool:
    # 여기에 풀이 작성
    pass

# %%
# 테스트
assert is_valid("()") == True
assert is_valid("()[]{}") == True
assert is_valid("(]") == False
assert is_valid("([)]") == False
assert is_valid("{[]}") == True
assert is_valid("") == True
print("All tests passed!")

# %% [markdown]
# ### 복기
# - 왜 이 패턴인지:
# - 시간/공간 복잡도:
# - 오늘 실수:
#
# ---

# %% [markdown]
# ## 2. Min Stack (LC 155) - Medium
# https://leetcode.com/problems/min-stack/
#
# **패턴**: 보조 스택으로 최솟값 추적
#
# **문제**: push, pop, top, getMin을 모두 O(1)에 수행하는 스택을 설계하라.
#
# ```
# push(-2), push(0), push(-3)
# getMin() → -3
# pop()
# top() → 0
# getMin() → -2
# ```

# %%
class MinStack:
    def __init__(self):
        # 여기에 초기화
        pass

    def push(self, val: int) -> None:
        pass

    def pop(self) -> None:
        pass

    def top(self) -> int:
        pass

    def getMin(self) -> int:
        pass

# %%
# 테스트
s = MinStack()
s.push(-2)
s.push(0)
s.push(-3)
assert s.getMin() == -3
s.pop()
assert s.top() == 0
assert s.getMin() == -2
print("All tests passed!")

# %% [markdown]
# ### 복기
# - 왜 이 패턴인지:
# - 시간/공간 복잡도:
# - 오늘 실수:
#
# ---

# %% [markdown]
# ## 3. Daily Temperatures (LC 739) - Medium
# https://leetcode.com/problems/daily-temperatures/
#
# **패턴**: 단조 스택 (Monotonic Stack)
#
# **문제**: 일별 온도 배열이 주어질 때, 각 날에 대해 "며칠 뒤에 더 따뜻한 날이 오는지" 배열을 반환하라. 없으면 0.
#
# ```
# Input: [73, 74, 75, 71, 69, 72, 76, 73]
# Output: [1, 1, 4, 2, 1, 1, 0, 0]
# ```
#
# **힌트**: 스택에 인덱스를 저장. 현재 온도가 스택 top의 온도보다 크면 pop하면서 답 기록.

# %%
from typing import List

def daily_temperatures(temperatures: List[int]) -> List[int]:
    # 여기에 풀이 작성
    pass

# %%
# 테스트
assert daily_temperatures([73, 74, 75, 71, 69, 72, 76, 73]) == [1, 1, 4, 2, 1, 1, 0, 0]
assert daily_temperatures([30, 40, 50, 60]) == [1, 1, 1, 0]
assert daily_temperatures([30, 20, 10]) == [0, 0, 0]
print("All tests passed!")

# %% [markdown]
# ### 복기
# - 왜 이 패턴인지:
# - 시간/공간 복잡도:
# - 오늘 실수:
#
# ---

# %% [markdown]
# ## 4. Implement Queue using Stacks (LC 232) - Easy
# https://leetcode.com/problems/implement-queue-using-stacks/
#
# **패턴**: 스택 2개로 큐 구현
#
# **문제**: 스택 2개만 사용해서 FIFO 큐를 구현하라.
#
# ```
# push(1), push(2)
# peek() → 1
# pop() → 1
# empty() → False
# ```
#
# **핵심**: 스택은 LIFO, 큐는 FIFO. 스택 2개를 쓰면 순서를 뒤집을 수 있다.

# %%
class MyQueue:
    def __init__(self):
        # 여기에 초기화
        pass

    def push(self, x: int) -> None:
        pass

    def pop(self) -> int:
        pass

    def peek(self) -> int:
        pass

    def empty(self) -> bool:
        pass

# %%
# 테스트
q = MyQueue()
q.push(1)
q.push(2)
assert q.peek() == 1
assert q.pop() == 1
assert q.empty() == False
assert q.pop() == 2
assert q.empty() == True
print("All tests passed!")

# %% [markdown]
# ### 복기
# - 왜 이 패턴인지:
# - 시간/공간 복잡도:
# - 오늘 실수:
#
# ---

# %% [markdown]
# ## 5. Evaluate Reverse Polish Notation (LC 150) - Medium
# https://leetcode.com/problems/evaluate-reverse-polish-notation/
#
# **패턴**: 스택으로 후위 표기식 계산
#
# **문제**: 후위 표기식 토큰 배열이 주어질 때, 계산 결과를 반환하라. 나눗셈은 0을 향해 버림.
#
# ```
# Input: ["2","1","+","3","*"] → 9  # ((2+1)*3)
# Input: ["4","13","5","/","+"] → 6  # (4+(13/5))
# ```
#
# **핵심**: 숫자면 push, 연산자면 2개 pop해서 계산 후 push.

# %%
from typing import List

def eval_rpn(tokens: List[str]) -> int:
    # 여기에 풀이 작성
    pass

# %%
# 테스트
assert eval_rpn(["2", "1", "+", "3", "*"]) == 9
assert eval_rpn(["4", "13", "5", "/", "+"]) == 6
assert eval_rpn(["10", "6", "9", "3", "+", "-11", "*", "/", "*", "17", "+", "5", "+"]) == 22
print("All tests passed!")

# %% [markdown]
# ### 복기
# - 왜 이 패턴인지:
# - 시간/공간 복잡도:
# - 오늘 실수:
