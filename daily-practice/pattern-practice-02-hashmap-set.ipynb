# %% [markdown]
# # 알고리즘 패턴 훈련 Part 2
#
# 2026-02-22 HashMap / Set 집중 훈련
#
# 핵심: `중복 검사`, `빈도수 카운팅`, `보완값(target - num) 탐색`
#
# ---

# %% [markdown]
# ## 오늘의 목표
#
# - `contains_duplicate`를 Set으로 풀 수 있다
# - `two_sum`을 Dict(HashMap)으로 O(n)에 풀 수 있다
# - `first_unique_char`를 빈도수 카운팅으로 풀 수 있다

# %% [markdown]
# ## Part 1: 중복 검사 (Set)

# %% [markdown]
# ### 문제 1-1: Contains Duplicate
# 정수 리스트 `nums`에 중복이 있으면 `True`, 없으면 `False`를 반환하세요.

# %%
def contains_duplicate(nums: list[int]) -> bool:
    # TODO: Set을 사용해서 구현
    seen = set()
    for num in nums:
        # 여기에 코드 작성
        pass
    return False

# 테스트
print(contains_duplicate([1, 2, 3, 1]))  # True
print(contains_duplicate([1, 2, 3, 4]))  # False
print(contains_duplicate([]))            # False

# %% [markdown]
# ---
# ## Part 2: 보완값 탐색 (HashMap)

# %% [markdown]
# ### 문제 2-1: Two Sum
# 정수 리스트 `nums`와 `target`이 주어집니다.
# 합이 `target`이 되는 두 수의 인덱스를 반환하세요. (정답은 하나라고 가정)

# %%
def two_sum(nums: list[int], target: int) -> list[int]:
    # TODO: Dict를 사용해서 O(n)으로 구현
    seen = {}  # {값: 인덱스}

    for i, num in enumerate(nums):
        need = target - num
        # 여기에 코드 작성
        pass

    return []

# 테스트
print(two_sum([2, 7, 11, 15], 9))  # [0, 1]
print(two_sum([3, 2, 4], 6))       # [1, 2]
print(two_sum([3, 3], 6))          # [0, 1]

# %% [markdown]
# ---
# ## Part 3: 빈도수 카운팅 (HashMap)

# %% [markdown]
# ### 문제 3-1: First Unique Character
# 문자열 `s`에서 한 번만 등장하는 첫 문자 인덱스를 반환하세요.
# 없으면 `-1`을 반환하세요.

# %%
def first_unique_char(s: str) -> int:
    # TODO: 1차 순회로 빈도수 저장, 2차 순회로 첫 인덱스 찾기
    freq = {}

    # 1) 빈도수 카운팅
    for ch in s:
        # 여기에 코드 작성
        pass

    # 2) 첫 unique 인덱스 찾기
    for i, ch in enumerate(s):
        # 여기에 코드 작성
        pass

    return -1

# 테스트
print(first_unique_char("leetcode"))      # 0
print(first_unique_char("loveleetcode"))  # 2
print(first_unique_char("aabb"))          # -1

# %% [markdown]
# ---
# ## 효율 학습 루틴 (취업 코테 기준)
#
# 1. 하루 1패턴만: 오늘은 HashMap/Set만
# 2. 문제당 30분 제한: 20분 막히면 해설 확인
# 3. 해설 본 문제는 바로 덮고 10분 안에 재구현
# 4. 복습 간격: D0, D1, D3, D7
# 5. 복기 3줄: 왜 이 패턴인지 / 시간복잡도 / 오늘 실수 1개

# %% [markdown]
# ---
# # 정답
#
# <details>
# <summary>전체 정답 보기 (클릭)</summary>
#
# ```python
# def contains_duplicate(nums: list[int]) -> bool:
#     seen = set()
#     for num in nums:
#         if num in seen:
#             return True
#         seen.add(num)
#     return False
#
# def two_sum(nums: list[int], target: int) -> list[int]:
#     seen = {}
#     for i, num in enumerate(nums):
#         need = target - num
#         if need in seen:
#             return [seen[need], i]
#         seen[num] = i
#     return []
#
# def first_unique_char(s: str) -> int:
#     freq = {}
#     for ch in s:
#         freq[ch] = freq.get(ch, 0) + 1
#
#     for i, ch in enumerate(s):
#         if freq[ch] == 1:
#             return i
#
#     return -1
# ```
#
# </details>
