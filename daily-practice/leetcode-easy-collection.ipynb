# %% [markdown]
# # LeetCode Easy 문제 모음
#
# 실제 코딩 테스트 대비 연습!
#
# ---

# %% [markdown]
# ## 1. Two Sum (LeetCode #1)
#
# 정수 배열 nums와 정수 target이 주어질 때, 합이 target이 되는 두 숫자의 인덱스를 반환하세요.
#
# - 각 입력에는 정확히 하나의 해답이 있다고 가정합니다.
# - 같은 요소를 두 번 사용할 수 없습니다.

# %%
def twoSum(nums: list, target: int) -> list:
    # 힌트: 딕셔너리로 이미 본 숫자와 인덱스 저장
    pass

# 테스트
print(twoSum([2, 7, 11, 15], 9))  # [0, 1]
print(twoSum([3, 2, 4], 6))       # [1, 2]
print(twoSum([3, 3], 6))          # [0, 1]

# %% [markdown]
# ## 2. Valid Anagram (LeetCode #242)
#
# 두 문자열 s와 t가 주어질 때, t가 s의 애너그램인지 확인하세요.
#
# - 애너그램: 같은 문자를 재배열해서 만든 단어

# %%
def isAnagram(s: str, t: str) -> bool:
    # 힌트: 문자 빈도수 딕셔너리 비교
    pass

# 테스트
print(isAnagram("anagram", "nagaram"))  # True
print(isAnagram("rat", "car"))          # False

# %% [markdown]
# ## 3. Contains Duplicate (LeetCode #217)
#
# 정수 배열 nums가 주어질 때, 중복된 값이 있으면 True, 없으면 False 반환

# %%
def containsDuplicate(nums: list) -> bool:
    # 힌트: set 활용
    pass

# 테스트
print(containsDuplicate([1, 2, 3, 1]))        # True
print(containsDuplicate([1, 2, 3, 4]))        # False
print(containsDuplicate([1, 1, 1, 3, 3, 4]))  # True

# %% [markdown]
# ## 4. Single Number (LeetCode #136)
#
# 비어 있지 않은 정수 배열 nums가 주어집니다. 모든 요소는 두 번씩 나타나고, 하나만 한 번 나타납니다.
# 한 번만 나타나는 요소를 찾으세요.
#
# - O(n) 시간, O(1) 공간으로 풀 수 있지만, 먼저 어떤 방법이든 풀어보세요!

# %%
def singleNumber(nums: list) -> int:
    # 힌트: 딕셔너리로 카운팅 또는 XOR 연산
    pass

# 테스트
print(singleNumber([2, 2, 1]))        # 1
print(singleNumber([4, 1, 2, 1, 2]))  # 4
print(singleNumber([1]))              # 1

# %% [markdown]
# ## 5. Valid Palindrome (LeetCode #125)
#
# 문자열 s가 주어질 때, 팰린드롬인지 확인하세요.
#
# - 영문자와 숫자만 고려합니다.
# - 대소문자를 구분하지 않습니다.

# %%
def isPalindrome(s: str) -> bool:
    # 힌트: 먼저 영문자/숫자만 필터링, 소문자로 변환, 뒤집어서 비교
    pass

# 테스트
print(isPalindrome("A man, a plan, a canal: Panama"))  # True
print(isPalindrome("race a car"))                       # False
print(isPalindrome(" "))                                # True

# %% [markdown]
# ## 6. Valid Parentheses (LeetCode #20)
#
# 괄호로만 이루어진 문자열 s가 주어질 때, 올바른 괄호인지 확인하세요.
#
# - 열린 괄호는 같은 유형의 괄호로 닫혀야 합니다.
# - 열린 괄호는 올바른 순서로 닫혀야 합니다.

# %%
def isValid(s: str) -> bool:
    # 힌트: 스택(리스트) 사용, 매칭 딕셔너리
    pass

# 테스트
print(isValid("()"))      # True
print(isValid("()[]{}"))  # True
print(isValid("(]"))      # False
print(isValid("([)]"))    # False
print(isValid("{[]}"))    # True

# %% [markdown]
# ## 7. Best Time to Buy and Sell Stock (LeetCode #121)
#
# 배열 prices가 주어집니다. prices[i]는 i번째 날의 주식 가격입니다.
# 한 번 사고 한 번 팔아서 얻을 수 있는 최대 이익을 반환하세요.
#
# - 이익을 얻을 수 없으면 0을 반환합니다.

# %%
def maxProfit(prices: list) -> int:
    # 힌트: 지금까지의 최소 가격 추적, 현재 가격과의 차이 계산
    pass

# 테스트
print(maxProfit([7, 1, 5, 3, 6, 4]))  # 5 (1에 사서 6에 팔기)
print(maxProfit([7, 6, 4, 3, 1]))     # 0 (이익 불가)

# %% [markdown]
# ## 8. Maximum Subarray (LeetCode #53)
#
# 정수 배열 nums가 주어질 때, 합이 최대인 연속 부분 배열을 찾고 그 합을 반환하세요.

# %%
def maxSubArray(nums: list) -> int:
    # 힌트: 현재까지의 합이 음수면 버리고 다시 시작 (카데인 알고리즘)
    pass

# 테스트
print(maxSubArray([-2, 1, -3, 4, -1, 2, 1, -5, 4]))  # 6 ([4,-1,2,1])
print(maxSubArray([1]))                              # 1
print(maxSubArray([5, 4, -1, 7, 8]))                 # 23

# %% [markdown]
# ## 9. Move Zeroes (LeetCode #283)
#
# 정수 배열 nums가 주어질 때, 모든 0을 배열 끝으로 이동하세요.
# 나머지 요소의 상대적 순서는 유지해야 합니다.
#
# - 새 배열을 만들지 않고 in-place로 수정하세요.

# %%
def moveZeroes(nums: list) -> None:
    # 힌트: 0이 아닌 값을 앞으로 모으고, 나머지를 0으로
    pass

# 테스트
test1 = [0, 1, 0, 3, 12]
moveZeroes(test1)
print(test1)  # [1, 3, 12, 0, 0]

test2 = [0]
moveZeroes(test2)
print(test2)  # [0]

# %% [markdown]
# ## 10. Majority Element (LeetCode #169)
#
# 크기가 n인 배열 nums가 주어질 때, 과반수 요소를 반환하세요.
# 과반수 요소는 n/2번 이상 나타나는 요소입니다.

# %%
def majorityElement(nums: list) -> int:
    # 힌트: 딕셔너리로 카운팅
    pass

# 테스트
print(majorityElement([3, 2, 3]))              # 3
print(majorityElement([2, 2, 1, 1, 1, 2, 2]))  # 2

# %% [markdown]
# ## 11. First Unique Character (LeetCode #387)
#
# 문자열 s에서 반복되지 않는 첫 번째 문자를 찾아 인덱스를 반환하세요.
# 없으면 -1을 반환하세요.

# %%
def firstUniqChar(s: str) -> int:
    # 힌트: 먼저 빈도수 딕셔너리 만들고, 다시 순회하며 1인 문자 찾기
    pass

# 테스트
print(firstUniqChar("leetcode"))     # 0 ('l')
print(firstUniqChar("loveleetcode")) # 2 ('v')
print(firstUniqChar("aabb"))         # -1

# %% [markdown]
# ## 12. Intersection of Two Arrays (LeetCode #349)
#
# 두 정수 배열 nums1과 nums2가 주어질 때, 교집합을 반환하세요.
# 결과의 각 요소는 고유해야 합니다.

# %%
def intersection(nums1: list, nums2: list) -> list:
    # 힌트: set 교집합 연산
    pass

# 테스트
print(sorted(intersection([1, 2, 2, 1], [2, 2])))     # [2]
print(sorted(intersection([4, 9, 5], [9, 4, 9, 8])))  # [4, 9]

# %% [markdown]
# ---
# # 정답
#
# <details>
# <summary>전체 정답 보기 (클릭)</summary>
#
# ```python
# # 1. Two Sum
# def twoSum(nums, target):
#     seen = {}
#     for i, num in enumerate(nums):
#         need = target - num
#         if need in seen:
#             return [seen[need], i]
#         seen[num] = i
#     return []
#
# # 2. Valid Anagram
# def isAnagram(s, t):
#     if len(s) != len(t):
#         return False
#     count = {}
#     for char in s:
#         count[char] = count.get(char, 0) + 1
#     for char in t:
#         count[char] = count.get(char, 0) - 1
#     for val in count.values():
#         if val != 0:
#             return False
#     return True
#
# # 3. Contains Duplicate
# def containsDuplicate(nums):
#     return len(nums) != len(set(nums))
#
# # 4. Single Number
# def singleNumber(nums):
#     count = {}
#     for num in nums:
#         count[num] = count.get(num, 0) + 1
#     for num, cnt in count.items():
#         if cnt == 1:
#             return num
#
# # 5. Valid Palindrome
# def isPalindrome(s):
#     filtered = ''
#     for char in s:
#         if char.isalnum():
#             filtered += char.lower()
#     return filtered == filtered[::-1]
#
# # 6. Valid Parentheses
# def isValid(s):
#     stack = []
#     pairs = {')': '(', ']': '[', '}': '{'}
#     for char in s:
#         if char in '([{':
#             stack.append(char)
#         else:
#             if not stack or stack[-1] != pairs[char]:
#                 return False
#             stack.pop()
#     return len(stack) == 0
#
# # 7. Best Time to Buy and Sell Stock
# def maxProfit(prices):
#     min_price = prices[0]
#     max_profit = 0
#     for price in prices:
#         if price < min_price:
#             min_price = price
#         profit = price - min_price
#         if profit > max_profit:
#             max_profit = profit
#     return max_profit
#
# # 8. Maximum Subarray (Kadane's Algorithm)
# def maxSubArray(nums):
#     current_sum = nums[0]
#     max_sum = nums[0]
#     for i in range(1, len(nums)):
#         if current_sum < 0:
#             current_sum = 0
#         current_sum += nums[i]
#         if current_sum > max_sum:
#             max_sum = current_sum
#     return max_sum
#
# # 9. Move Zeroes
# def moveZeroes(nums):
#     pos = 0
#     for i in range(len(nums)):
#         if nums[i] != 0:
#             nums[pos] = nums[i]
#             pos += 1
#     while pos < len(nums):
#         nums[pos] = 0
#         pos += 1
#
# # 10. Majority Element
# def majorityElement(nums):
#     count = {}
#     for num in nums:
#         count[num] = count.get(num, 0) + 1
#     half = len(nums) // 2
#     for num, cnt in count.items():
#         if cnt > half:
#             return num
#
# # 11. First Unique Character
# def firstUniqChar(s):
#     count = {}
#     for char in s:
#         count[char] = count.get(char, 0) + 1
#     for i, char in enumerate(s):
#         if count[char] == 1:
#             return i
#     return -1
#
# # 12. Intersection of Two Arrays
# def intersection(nums1, nums2):
#     return list(set(nums1) & set(nums2))
# ```
#
# </details>
