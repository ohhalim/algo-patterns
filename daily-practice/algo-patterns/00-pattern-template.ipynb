# %% [markdown]
# # 00. 알고리즘 패턴 공통 템플릿
#
# 새 패턴을 시작할 때 이 노트북을 복사해서 사용하세요.

# %% [markdown]
# ## 1) 패턴 신호
# - 문제에서 어떤 문구가 보이면 이 패턴을 의심할지 적기
# - 입력 크기(n), 정렬 여부, 중복 허용 여부 기록
#
# ## 2) 브루트포스 -> 최적화
# 1. 브루트포스 아이디어와 시간복잡도
# 2. 병목 구간(중복 탐색, 불필요한 재계산) 파악
# 3. 자료구조/패턴으로 개선한 아이디어와 시간복잡도
#
# ## 3) 대표 문제 3개
# 1. Easy 1개
# 2. Easy~Medium 1개
# 3. Medium 1개
#
# ## 4) 실수 체크리스트
# - 경계값(빈 배열, 원소 1개)
# - 인덱스 범위
# - 중복/음수/정렬 조건 누락
#
# ## 5) 복습 주기
# - D+1: 다시 풀기 (힌트 최소화)
# - D+7: 10~15분 제한으로 다시 풀기
# - D+30: 5분 내 핵심 풀이 재현

# %%
# 새 패턴 시작용 공통 코드 틀
def solve(input_data):
    # 1) 브루트포스 접근 요약
    # 2) 최적화 포인트
    # 3) 최종 구현
    pass

# 예시
print(solve(None))
