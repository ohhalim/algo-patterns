# %% [markdown]
# # 10. Linked List Basics
#
# 포인터(참조) 이동에 익숙해지는 단계.

# %% [markdown]
# ## 패턴 신호
# - 중간 삽입/삭제가 잦은 구조
# - 순차 이동하며 참조 연결 변경
# - 사이클 탐지, 중간 노드 찾기
#
# ## 브루트포스 -> 최적화
# 1. 배열로 바꿔서 처리(쉬움, 추가 메모리 사용)
# 2. 포인터만으로 in-place 처리(O(1) extra space)

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def build_linked_list(values):
    dummy = ListNode()
    cur = dummy
    for v in values:
        cur.next = ListNode(v)
        cur = cur.next
    return dummy.next

def to_list(head):
    out = []
    cur = head
    while cur:
        out.append(cur.val)
        cur = cur.next
    return out

# %% [markdown]
# ---
# ## 문제 1: Reverse Linked List
# **힌트**: `prev`, `cur`, `next_node` 세 포인터 사용

# %%
def reverse_list(head):
    # 여기에 코드를 작성하세요
    pass

head = build_linked_list([1, 2, 3, 4, 5])
print(to_list(reverse_list(head)))  # [5,4,3,2,1]

# %% [markdown]
# ---
# ## 문제 2: Linked List Cycle
# **힌트**: fast/slow 포인터가 만나면 사이클 존재

# %%
def has_cycle(head):
    # 여기에 코드를 작성하세요
    pass

a = ListNode(3)
b = ListNode(2)
c = ListNode(0)
d = ListNode(-4)
a.next = b
b.next = c
c.next = d
d.next = b
print(has_cycle(a))  # True

print(has_cycle(build_linked_list([1, 2, 3])))  # False

# %% [markdown]
# ---
# ## 문제 3: Merge Two Sorted Lists
# **힌트**: dummy 노드를 두고 작은 값을 계속 연결

# %%
def merge_two_lists(list1, list2):
    # 여기에 코드를 작성하세요
    pass

l1 = build_linked_list([1, 2, 4])
l2 = build_linked_list([1, 3, 4])
print(to_list(merge_two_lists(l1, l2)))  # [1,1,2,3,4,4]

# %% [markdown]
# ---
# ## 복습 체크
# - D+1: reverse, cycle 재풀이
# - D+7: merge를 15분 제한으로 재풀이
# - D+30: 세 문제 모두 포인터 그림 없이 구현
