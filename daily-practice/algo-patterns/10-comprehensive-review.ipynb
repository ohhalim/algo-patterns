# %% [markdown]
# # 10. 종합 복습 (Comprehensive Review)
#
# 1~9번에서 배운 모든 패턴이 섞인 실전 문제! 어떤 패턴을 쓸지 직접 판단해야 합니다.
#
# ---
#
# ## 패턴 판단 가이드
#
# | 문제 유형 | 사용할 패턴 |
# |----------|------------|
# | 정렬된 배열 + 탐색 | Binary Search |
# | 연속 부분 배열/문자열 | Sliding Window |
# | 개수 세기, 중복 체크 | HashMap/Counter |
# | 배열 재배치, 비교 | Two Pointer |
# | 매 순간 최선의 선택 | Greedy |
# | 자기 자신을 반복 호출 | Recursion |
# | 같은 수 XOR = 0 | Bit Manipulation |

# %% [markdown]
# ---
# ## 문제 1: 배열에서 두 번째로 큰 수
# 배열에서 두 번째로 큰 수를 반환. 같은 값이면 하나로 취급 (예: [5, 5, 4] -> 4)
#
# **어떤 패턴?** 스스로 생각해보세요!

# %%
def second_largest(nums):
    # 여기에 코드를 작성하세요
    pass

# 테스트
print(second_largest([3, 1, 4, 1, 5, 9]))  # 5
print(second_largest([5, 5, 4]))            # 4
print(second_largest([10, 20]))             # 10
print(second_largest([1, 1, 1]))            # None (두 번째가 없음)

# %% [markdown]
# ---
# ## 문제 2: 합이 K인 부분 배열 개수
# 배열에서 합이 k인 연속 부분 배열의 개수를 반환
#
# **어떤 패턴?** 스스로 생각해보세요! (힌트: 누적합 + HashMap)

# %%
def subarray_sum(nums, k):
    # 여기에 코드를 작성하세요
    pass

# 테스트
print(subarray_sum([1, 1, 1], 2))       # 2
print(subarray_sum([1, 2, 3], 3))       # 2 ([1,2], [3])
print(subarray_sum([1, -1, 0], 0))      # 3

# %% [markdown]
# ---
# ## 문제 3: 문자열에서 모든 애너그램 찾기
# 문자열 s에서 문자열 p의 애너그램이 시작되는 인덱스를 모두 반환
#
# **어떤 패턴?** 스스로 생각해보세요!

# %%
def find_anagrams(s, p):
    # 여기에 코드를 작성하세요
    pass

# 테스트
print(find_anagrams("cbaebabacd", "abc"))  # [0, 6]
print(find_anagrams("abab", "ab"))         # [0, 1, 2]
print(find_anagrams("aaaa", "a"))          # [0, 1, 2, 3]

# %% [markdown]
# ---
# ## 문제 4: 배열 회전
# 배열을 오른쪽으로 k칸 회전시키세요. in-place로!
#
# [1, 2, 3, 4, 5, 6, 7], k=3 -> [5, 6, 7, 1, 2, 3, 4]
#
# **어떤 패턴?** 스스로 생각해보세요!

# %%
def rotate_array(nums, k):
    # 여기에 코드를 작성하세요 (nums 자체를 변경)
    pass

# 테스트
arr1 = [1, 2, 3, 4, 5, 6, 7]
rotate_array(arr1, 3)
print(arr1)  # [5, 6, 7, 1, 2, 3, 4]

arr2 = [-1, -100, 3, 99]
rotate_array(arr2, 2)
print(arr2)  # [3, 99, -1, -100]

# %% [markdown]
# ---
# ## 문제 5: 가장 가까운 두 수의 합
# 정렬된 배열에서 합이 target에 가장 가까운 두 수의 합을 반환
#
# **어떤 패턴?** 스스로 생각해보세요!

# %%
def two_sum_closest(nums, target):
    # 여기에 코드를 작성하세요
    pass

# 테스트
print(two_sum_closest([1, 2, 4, 8, 16], 15))   # 12 (4+8) 또는 17 (1+16)
print(two_sum_closest([-1, 2, 1, -4], 4))       # 3 (2+1)
print(two_sum_closest([1, 2, 3], 6))            # 5 (2+3)

# %% [markdown]
# ---
# ## 문제 6: 중복 문자 없이 가장 긴 부분 문자열 + 그 문자열 반환
# 길이만이 아니라 실제 부분 문자열도 함께 반환
#
# **어떤 패턴?** 스스로 생각해보세요!

# %%
def longest_unique_substring(s):
    # (길이, 부분문자열) 튜플 반환
    # 여기에 코드를 작성하세요
    pass

# 테스트
print(longest_unique_substring("abcabcbb"))  # (3, "abc")
print(longest_unique_substring("bbbbb"))     # (1, "b")
print(longest_unique_substring("pwwkew"))    # (3, "wke")
print(longest_unique_substring(""))           # (0, "")

# %% [markdown]
# ---
# ## 문제 7: Plus One
# 배열로 표현된 큰 정수에 1을 더하세요. [1, 2, 3] -> [1, 2, 4], [9, 9, 9] -> [1, 0, 0, 0]
#
# **어떤 패턴?** 스스로 생각해보세요!

# %%
def plus_one(digits):
    # 여기에 코드를 작성하세요
    pass

# 테스트
print(plus_one([1, 2, 3]))     # [1, 2, 4]
print(plus_one([4, 3, 2, 1]))  # [4, 3, 2, 2]
print(plus_one([9]))           # [1, 0]
print(plus_one([9, 9, 9]))     # [1, 0, 0, 0]

# %% [markdown]
# ---
# ## 문제 8: 두 정렬된 배열 합치기 (Merge Sorted Array)
# 정렬된 배열 nums1 (뒤에 0으로 공간 확보)과 nums2를 합쳐서 정렬된 하나의 배열로 만드세요. in-place로!
#
# **어떤 패턴?** 스스로 생각해보세요!

# %%
def merge_sorted(nums1, m, nums2, n):
    # nums1에 m개의 유효 원소, nums2에 n개의 원소
    # nums1의 크기는 m + n (뒤에 0으로 패딩)
    # 여기에 코드를 작성하세요 (nums1 자체를 변경)
    pass

# 테스트
arr1 = [1, 2, 3, 0, 0, 0]
merge_sorted(arr1, 3, [2, 5, 6], 3)
print(arr1)  # [1, 2, 2, 3, 5, 6]

arr2 = [1]
merge_sorted(arr2, 1, [], 0)
print(arr2)  # [1]

arr3 = [0]
merge_sorted(arr3, 0, [1], 1)
print(arr3)  # [1]
