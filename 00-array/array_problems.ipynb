# %% [markdown]
# # 00. Array (list)
#
# **핵심**: 순회, 인덱스 조작, in-place 변환, 구간 합(prefix sum)
#
# ## 언제 배열 조작을 쓰냐
# - "정렬된 배열에서 제자리로" → in-place 포인터
# - "나 자신을 제외한 ~" → prefix/suffix 분리
# - "구간을 합치거나 겹침 판단" → 정렬 후 순회
# - "배열을 O(1) 공간으로 변형" → 뒤집기, 스왑
#
# ## 템플릿
# ```python
# # in-place 덮어쓰기 (slow/fast 포인터)
# slow = 0
# for fast in range(len(nums)):
#     if nums[fast] != nums[slow]:
#         slow += 1
#         nums[slow] = nums[fast]
#
# # prefix sum
# prefix = [0] * (len(nums) + 1)
# for i in range(len(nums)):
#     prefix[i + 1] = prefix[i] + nums[i]
# # 구간 합: sum(nums[l:r]) = prefix[r] - prefix[l]
# ```
#
# ---

# %% [markdown]
# ## 1. Remove Duplicates from Sorted Array (LC 26) - Easy
# https://leetcode.com/problems/remove-duplicates-from-sorted-array/
#
# **패턴**: in-place slow/fast 포인터
#
# **문제**: 정렬된 정수 배열 `nums`가 주어질 때, 중복을 제거하고 고유한 원소의 개수를 반환하라. 배열은 in-place로 수정해야 한다.
#
# ```
# Input: nums = [1, 1, 2]
# Output: 2, nums = [1, 2, _]
#
# Input: nums = [0, 0, 1, 1, 1, 2, 2, 3, 3, 4]
# Output: 5, nums = [0, 1, 2, 3, 4, _, _, _, _, _]
# ```
#
# **제약**: 추가 배열 사용 불가. O(1) 추가 메모리.

# %%
from typing import List

def remove_duplicates(nums: List[int]) -> int:
    # 여기에 풀이 작성
    pass

# %%
# 테스트
nums1 = [1, 1, 2]
assert remove_duplicates(nums1) == 2
assert nums1[:2] == [1, 2]

nums2 = [0, 0, 1, 1, 1, 2, 2, 3, 3, 4]
assert remove_duplicates(nums2) == 5
assert nums2[:5] == [0, 1, 2, 3, 4]

nums3 = [1]
assert remove_duplicates(nums3) == 1
print("All tests passed!")

# %% [markdown]
# ### 복기
# - 왜 이 패턴인지:
# - 시간/공간 복잡도:
# - 오늘 실수:
#
# ---

# %% [markdown]
# ## 2. Best Time to Buy and Sell Stock (LC 121) - Easy
# https://leetcode.com/problems/best-time-to-buy-and-sell-stock/
#
# **패턴**: 최솟값 추적 + 최대 이익 갱신
#
# **문제**: 주식 가격 배열 `prices`가 주어질 때, 한 번 사고 한 번 팔아서 얻을 수 있는 최대 이익을 반환하라. 이익을 낼 수 없으면 0을 반환.
#
# ```
# Input: prices = [7, 1, 5, 3, 6, 4]
# Output: 5  # 1에 사서 6에 팔기
#
# Input: prices = [7, 6, 4, 3, 1]
# Output: 0  # 가격이 계속 하락하므로 이익 없음
# ```
#
# **제약**: 반드시 사고 난 뒤에 팔아야 한다 (매수일 < 매도일).

# %%
from typing import List

def max_profit(prices: List[int]) -> int:
    # 여기에 풀이 작성
    pass

# %%
# 테스트
assert max_profit([7, 1, 5, 3, 6, 4]) == 5
assert max_profit([7, 6, 4, 3, 1]) == 0
assert max_profit([2, 4, 1]) == 2
assert max_profit([1]) == 0
print("All tests passed!")

# %% [markdown]
# ### 복기
# - 왜 이 패턴인지:
# - 시간/공간 복잡도:
# - 오늘 실수:
#
# ---

# %% [markdown]
# ## 3. Rotate Array (LC 189) - Medium
# https://leetcode.com/problems/rotate-array/
#
# **패턴**: 뒤집기 3번 트릭 (reverse)
#
# **문제**: 정수 배열 `nums`를 오른쪽으로 `k`칸 회전시켜라. in-place로 수행.
#
# ```
# Input: nums = [1, 2, 3, 4, 5, 6, 7], k = 3
# Output: [5, 6, 7, 1, 2, 3, 4]
#
# Input: nums = [-1, -100, 3, 99], k = 2
# Output: [3, 99, -1, -100]
# ```
#
# **제약**: O(1) 추가 공간으로 풀어야 한다.

# %%
from typing import List

def rotate(nums: List[int], k: int) -> None:
    # 여기에 풀이 작성
    pass

# %%
# 테스트
nums1 = [1, 2, 3, 4, 5, 6, 7]
rotate(nums1, 3)
assert nums1 == [5, 6, 7, 1, 2, 3, 4]

nums2 = [-1, -100, 3, 99]
rotate(nums2, 2)
assert nums2 == [3, 99, -1, -100]

nums3 = [1, 2]
rotate(nums3, 3)
assert nums3 == [2, 1]
print("All tests passed!")

# %% [markdown]
# ### 복기
# - 왜 이 패턴인지:
# - 시간/공간 복잡도:
# - 오늘 실수:
#
# ---

# %% [markdown]
# ## 4. Product of Array Except Self (LC 238) - Medium
# https://leetcode.com/problems/product-of-array-except-self/
#
# **패턴**: prefix/suffix 곱
#
# **문제**: 정수 배열 `nums`가 주어질 때, `answer[i]`가 `nums[i]`를 제외한 나머지 모든 원소의 곱이 되는 배열을 반환하라.
#
# ```
# Input: nums = [1, 2, 3, 4]
# Output: [24, 12, 8, 6]
#
# Input: nums = [-1, 1, 0, -3, 3]
# Output: [0, 0, 9, 0, 0]
# ```
#
# **제약**: 나눗셈 연산 사용 금지. O(n) 시간.

# %%
from typing import List

def product_except_self(nums: List[int]) -> List[int]:
    # 여기에 풀이 작성
    pass

# %%
# 테스트
assert product_except_self([1, 2, 3, 4]) == [24, 12, 8, 6]
assert product_except_self([-1, 1, 0, -3, 3]) == [0, 0, 9, 0, 0]
assert product_except_self([2, 3]) == [3, 2]
print("All tests passed!")

# %% [markdown]
# ### 복기
# - 왜 이 패턴인지:
# - 시간/공간 복잡도:
# - 오늘 실수:
#
# ---

# %% [markdown]
# ## 5. Merge Intervals (LC 56) - Medium
# https://leetcode.com/problems/merge-intervals/
#
# **패턴**: 정렬 후 병합
#
# **문제**: 구간 배열 `intervals`가 주어질 때, 겹치는 구간을 모두 병합하여 반환하라.
#
# ```
# Input: intervals = [[1,3],[2,6],[8,10],[15,18]]
# Output: [[1,6],[8,10],[15,18]]
#
# Input: intervals = [[1,4],[4,5]]
# Output: [[1,5]]
# ```

# %%
from typing import List

def merge(intervals: List[List[int]]) -> List[List[int]]:
    # 여기에 풀이 작성
    pass

# %%
# 테스트
assert merge([[1,3],[2,6],[8,10],[15,18]]) == [[1,6],[8,10],[15,18]]
assert merge([[1,4],[4,5]]) == [[1,5]]
assert merge([[1,4],[0,4]]) == [[0,4]]
assert merge([[1,4],[2,3]]) == [[1,4]]
print("All tests passed!")

# %% [markdown]
# ### 복기
# - 왜 이 패턴인지:
# - 시간/공간 복잡도:
# - 오늘 실수:
